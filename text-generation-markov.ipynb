# %% [markdown]
# # Text Generation using a Markov Chain
#
# We'll be using code from this repository on [Github](https://github.com/jsvine/markovify).
#
# ### Import the package

# %%
# !pip install markovify
import markovify
# Out:
# Collecting markovify
#   Downloading https://files.pythonhosted.org/packages/94/b2/b4ce1e461bb3482b1fd63328a2097aed5917cdfa0dbfe9492a84ea46e2ab/markovify-0.7.1.tar.gz
# Collecting unidecode (from markovify)
#   Downloading https://files.pythonhosted.org/packages/31/39/53096f9217b057cb049fe872b7fc7ce799a1a89b76cf917d9639e7a558b5/Unidecode-1.0.23-py2.py3-none-any.whl (237kB)
#     100% |████████████████████████████████| 245kB 2.3MB/s ta 0:00:01
# Installing collected packages: unidecode, markovify
#   Running setup.py install for markovify ... done
# Successfully installed markovify-0.7.1 unidecode-1.0.23
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ### Pull in the raw text

# %%
with open("sonnets.txt") as f:
    text = f.read()

# %% [markdown]
# ### Build the model

# %%
text_model = markovify.Text(text)

# %% [markdown]
# ### Print 5 sentences generated by the model

# %%
for i in range(5):
    print(text_model.make_sentence())
# Out:
# None
# XVII Who will believe my verse ever live young.
# XVII Who will believe my verse ever live young.
# O! let my looks be then the eloquence And dumb presagers of my heart, Which in my rhyme.
# Ah! if thou issueless shalt hap to die, The world will be the tomb, Of his self-love to stop posterity?

# %% [markdown]
# ### Print three generated sentences of no more than 140 characters

# %%
# Print three randomly-generated sentences of no more than 140 characters
for i in range(3):
    print(text_model.make_short_sentence(140))
# Out:
# IV Unthrifty loveliness, why dost thou abuse The bounteous largess given thee to a summer's day?
# XXII My glass shall not persuade me I am old, So long lives this, and this gives life to thee.
# And fortify your self in single life?
